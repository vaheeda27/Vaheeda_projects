# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv(r"C:\Users\udaya\OneDrive\Desktop\vaheeda_mitraz\vaheeda_python\project\Attribute DataSet.csv")
inp1= pd.read_csv(r"C:\Users\udaya\OneDrive\Desktop\vaheeda_mitraz\vaheeda_python\project\Dress Sales.csv")

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# 1          Petal     microfiber         NaN     ruffles       animal
# 2           full       polyster         NaN         NaN        print
# 3           full           silk     chiffon  embroidary        print
# 4      butterfly  chiffonfabric     chiffon         bow          dot
# ..           ...            ...         ...         ...          ...
# 474   halfsleeve        acrylic     chiffon         NaN      striped
# 475         full       polyster         NaN         NaN        solid
# 476         full         cotton         NaN        lace        solid
# 477    sleevless           silk  broadcloth    applique        print
# 478        short         cotton    Corduroy        lace        solid
#
#      Recommendation
# 0                 1
# 1                 0
# 2                 0
# 3                 1
# 4                 0
# ..              ...
# 474               0
# 475               1
# 476               1
# 477               1
# 478               0
#
# [479 rows x 13 columns]

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %% [markdown]
# ### Fixing the Rows and Columns

# %%
# Print the information about the attributes of inp0 and inp1.
inp0.info()
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
#  19  10-04-2013  221 non-null    float64
#  20  10-06-2013  479 non-null    int64
#  21  10-08-2013  224 non-null    float64
#  22  10-10-2013  224 non-null    float64
#  23  10-12-2013  479 non-null    int64
# dtypes: float64(7), int64(11), object(6)
# memory usage: 89.9+ KB

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
size_map = {
    "M": "Medium",
    "L": "Large",
    "XL": "Extra Large",
    "free": "Free",
    "S": "Small",
    "s": "Small",
    "small": "Small"
}
inp0['Size']=inp0['Size'].replace(size_map,regex=True)

size_counts = inp0['Size'].value_counts()
total_entries = len(inp1)
size_percentages = size_counts / total_entries * 100
lowest_perc = size_percentages.min()
highest_perc = size_percentages.max()
small_perc = size_percentages.get('Small', 0)  # Use 0 if 'Small' is not present

print("Lowest percentage:", lowest_perc, "%")
print("Highest percentage:", highest_perc, "%")
print("Percentage of 'Small' size:", small_perc, "%")
# Out:
# Lowest percentage: 0.20876826722338201 %
# Highest percentage: 35.699373695198325 %
# Percentage of 'Small' size: 7.306889352818372 %

# %%
inp1
# Out:
#          Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1.006033e+09        2114        2274        2491        2660        2727
# 1    1.212192e+09         151         275         570         750         813
# 2    1.190381e+09           6           7           7           7           8
# 3    9.660060e+08        1005        1128        1326        1455        1507
# 4    8.763395e+08         996        1175        1304        1396        1432
# ..            ...         ...         ...         ...         ...         ...
# 474  9.905592e+08           0           0           0          60          62
# 475  7.133920e+08           0           0           0         560         554
# 476  5.328743e+08           0           0           0         734         728
# 477  6.554649e+08           0           0           0         254         259
# 478  9.199310e+08           0           0           0         538         545
#
#      09-08-2013  09-10-2013 09-12-2013 14-09-2013  ... 24-09-2013 26-09-2013  \
# 0          2887        2930       3119       3204  ...       3554     3624.0
# 1          1066        1164       1558       1756  ...       2710     2942.0
# 2             8           9         10         10  ...         11       11.0
# 3          1621        1637       1723       1746  ...       1878     1892.0
# 4          1559        1570       1638       1655  ...       2032     2156.0
# ..          ...         ...        ...        ...  ...        ...        ...
# 474          64          65         67         68  ...         73       74.0
# 475         544         537        525        519  ...        400      388.0
# 476         726         715        694        690  ...        616      597.0
# 477         261         263        268        270  ...        257      256.0
# 478         558         563        578        585  ...        628      632.0
#
#     28-09-2013 30-09-2013  10-02-2013  10-04-2013  10-06-2013  10-08-2013  \
# 0         3706     3746.0      3795.0      3832.0        3897      3923.0
# 1         3258     3354.0      3475.0      3654.0        3911      4024.0
# 2           11       11.0        11.0        11.0          11        11.0
# 3         1914     1924.0      1929.0      1941.0        1952      1955.0
# 4         2252     2312.0      2387.0      2459.0        2544      2614.0
# ..         ...        ...         ...         ...         ...         ...
# 474         75       75.0        76.0        76.0          77        77.0
# 475        360      364.0       372.0       377.0         380       382.0
# 476        586      569.0       561.0       555.0         551       546.0
# 477        255      254.0       253.0       250.0         249       249.0
# 478        639      645.0       651.0       655.0         660       668.0
#
#      10-10-2013  10-12-2013
# 0        3985.0        4048
# 1        4125.0        4277
# 2          11.0          11
# 3        1959.0        1963
# 4        2693.0        2736
# ..          ...         ...
# 474        77.0          77
# 475       384.0         285
# 476       535.0         520
# 477       249.0         248
# 478       674.0         680
#
# [479 rows x 24 columns]

# %%
# Print the value counts of each category in "Size" column.
sizecount=inp0['Size'].value_counts()
sizecount
# Out:
# Size
# Medium             171
# Free               165
# Large               93
# Small               35
# Extra Largearge     14
# Smallmall            1
# Name: count, dtype: int64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
null_inp0=inp0.isnull().sum()
null_inp1=inp1.isnull().sum()
print(null_inp0)
print(null_inp1)
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
#  19  10-04-2013  221 non-null    float64
#  20  10-06-2013  479 non-null    int64
#  21  10-08-2013  224 non-null    float64
#  22  10-10-2013  224 non-null    float64
#  23  10-12-2013  479 non-null    int64
# dtypes: float64(7), int64(11), object(6)
# memory usage: 89.9+ KB

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
date_columns =['09-12-2013', '14-09-2013', '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013']
for col in date_columns:
    inp1[col] = pd.to_numeric(inp1[col], errors='coerce')
    inp1[col].fillna(0, inplace=True)

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
#  19  10-04-2013  221 non-null    float64
#  20  10-06-2013  479 non-null    int64
#  21  10-08-2013  224 non-null    float64
#  22  10-10-2013  224 non-null    float64
#  23  10-12-2013  479 non-null    int64
# dtypes: float64(7), int64(11), object(6)
# memory usage: 89.9+ KB

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
percent_missing = inp1.isnull().mean() * 100

percent_missing
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.000000
# 14-09-2013     0.000000
# 16-09-2013     0.000000
# 18-09-2013     0.000000
# 20-09-2013     0.000000
# 22-09-2013     0.000000
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
columns_to_drop = percent_missing[percent_missing > 40].index

# Drop the columns
inp1.drop(columns_to_drop, axis=1, inplace=True)

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  28-09-2013  479 non-null    int64
#  16  10-06-2013  479 non-null    int64
#  17  10-12-2013  479 non-null    int64
# dtypes: float64(1), int64(11), object(6)
# memory usage: 67.5+ KB

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
def get_season(month):
    if month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    elif month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'

for col in inp1.columns[1:]: 
    # Extract the month from the column name
    month = int(col.split('-')[1])
    season = get_season(month)

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
season_sales = {
    'Summer': 0,
    'Autumn': 0,
    'Winter': 0,
    'Spring': 0
}

# Calculate the sum of sales for each season
for col in inp1.columns[1:]:  # Skip 'Dress_ID'
    month = int(col.split('-')[1])
    season = get_season(month)
    
    # Sum the sales for the season
    season_sales[season] += inp1[col].sum()

# Print the result
print(season_sales)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[16], line 15
#      12     season = get_season(month)
#      14     # Sum the sales for the season
# ---> 15     season_sales[season] += inp1[col].sum()
#      17 # Print the result
#      18 print(season_sales)
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('int64'), dtype('<U1228')) -> None

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 09-12-2013 14-09-2013  16-09-2013  \
# 0            NaN    chiffon  ...       3119       3204        3277
# 1     microfiber        NaN  ...       1558       1756        1878
# 2       polyster        NaN  ...         10         10          10
# 3           silk    chiffon  ...       1723       1746        1783
# 4  chiffonfabric    chiffon  ...       1638       1655        1681
#
#    18-09-2013  20-09-2013  22-09-2013  24-09-2013  28-09-2013  10-06-2013  \
# 0        3321        3386        3479        3554        3706        3897
# 1        1985        2106        2454        2710        3258        3911
# 2          10          10          11          11          11          11
# 3        1796        1812        1845        1878        1914        1952
# 4        1743        1824        1919        2032        2252        2544
#
#    10-12-2013
# 0        4048
# 1        4277
# 2          11
# 3        1963
# 4        2736
#
# [5 rows x 30 columns]

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Automn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  ... 09-12-2013 14-09-2013  \
# 0      sleevless            NaN     chiffon  ...       3119       3204
# 1          Petal     microfiber         NaN  ...       1558       1756
# 2           full       polyster         NaN  ...         10         10
# 3           full           silk     chiffon  ...       1723       1746
# 4      butterfly  chiffonfabric     chiffon  ...       1638       1655
# ..           ...            ...         ...  ...        ...        ...
# 474   halfsleeve        acrylic     chiffon  ...         67         68
# 475         full       polyster         NaN  ...        525        519
# 476         full         cotton         NaN  ...        694        690
# 477    sleevless           silk  broadcloth  ...        268        270
# 478        short         cotton    Corduroy  ...        578        585
#
#      16-09-2013  18-09-2013  20-09-2013  22-09-2013  24-09-2013  28-09-2013  \
# 0          3277        3321        3386        3479        3554        3706
# 1          1878        1985        2106        2454        2710        3258
# 2            10          10          10          11          11          11
# 3          1783        1796        1812        1845        1878        1914
# 4          1681        1743        1824        1919        2032        2252
# ..          ...         ...         ...         ...         ...         ...
# 474          69          70          72          73          73          75
# 475         511         501         492         480         400         360
# 476         686         674         665         658         616         586
# 477         272         272         264         264         257         255
# 478         590         599         605         619         628         639
#
#      10-06-2013  10-12-2013
# 0          3897        4048
# 1          3911        4277
# 2            11          11
# 3          1952        1963
# 4          2544        2736
# ..          ...         ...
# 474          77          77
# 475         380         285
# 476         551         520
# 477         249         248
# 478         660         680
#
# [479 rows x 30 columns]

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0['Price'].fillna(inp0['Price'].mode(), inplace=True)

inp0['Season'].fillna(inp0['Season'].mode()[0], inplace=True)

inp0['NeckLine'].fillna(inp0['NeckLine'].mode()[0], inplace=True)

inp0['SleeveLength'].fillna(inp0['SleeveLength'].mode()[0], inplace=True)

inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Automn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# 1          Petal     microfiber         NaN     ruffles       animal
# 2           full       polyster         NaN         NaN        print
# 3           full           silk     chiffon  embroidary        print
# 4      butterfly  chiffonfabric     chiffon         bow          dot
# ..           ...            ...         ...         ...          ...
# 474   halfsleeve        acrylic     chiffon         NaN      striped
# 475         full       polyster         NaN         NaN        solid
# 476         full         cotton         NaN        lace        solid
# 477    sleevless           silk  broadcloth    applique        print
# 478        short         cotton    Corduroy        lace        solid
#
#      Recommendation
# 0                 1
# 1                 0
# 2                 0
# 3                 1
# 4                 0
# ..              ...
# 474               0
# 475               1
# 476               1
# 477               1
# 478               0
#
# [479 rows x 13 columns]

# %%
percent_missing = inp0.isnull().mean() * 100
percent_missing
# Out:
# Dress_ID           0.000000
# Style              0.000000
# Price              0.417537
# Rating             0.000000
# Size               0.000000
# Season             0.000000
# NeckLine           0.000000
# SleeveLength       0.000000
# Material          24.843424
# FabricType        53.444676
# Decoration        46.764092
# Pattern Type      21.294363
# Recommendation     0.000000
# dtype: float64

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0['Material'].fillna(inp0['Material'].mode()[0], inplace=True)
inp0['Pattern Type'].fillna(inp0['Pattern Type'].mode()[0], inplace=True)   
#Using 'Unknown' placeholder for missing values more than 40%
inp0['FabricType'].fillna('Unknown', inplace=True)
inp0['Decoration'].fillna('Unknown', inplace=True)

# %%
percent_missing = inp0.isnull().mean() * 100
percent_missing
# Out:
# Dress_ID          0.000000
# Style             0.000000
# Price             0.417537
# Rating            0.000000
# Size              0.000000
# Season            0.000000
# NeckLine          0.000000
# SleeveLength      0.000000
# Material          0.000000
# FabricType        0.000000
# Decoration        0.000000
# Pattern Type      0.000000
# Recommendation    0.000000
# dtype: float64

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
columns=['Season', 'NeckLine','Price', 'Material', 'Decoration','SleeveLength']
for col in columns:
    unique_values = inp0[col].unique()
    print(f'{col} = {unique_values}\n')
# Out:
# Season = ['Summer' 'Automn' 'Spring' 'Winter' 'spring' 'winter' 'Autumn']
#
# NeckLine = ['o-neck' 'v-neck' 'boat-neck' 'peterpan-collor' 'ruffled'
#  'turndowncollor' 'slash-neck' 'mandarin-collor' 'open' 'sqare-collor'
#  'Sweetheart' 'sweetheart' 'Scoop' 'halter' 'backless' 'bowneck']
#
# Price = ['Low' 'High' 'Average' 'Medium' 'very-high' nan]
#
# Material = ['cotton' 'microfiber' 'polyster' 'silk' 'chiffonfabric' 'nylon' 'other'
#  'milksilk' 'linen' 'rayon' 'lycra' 'mix' 'acrylic' 'spandex' 'lace'
#  'modal' 'cashmere' 'viscos' 'sill' 'wool' 'model' 'shiffon']
#
# Decoration = ['ruffles' 'Unknown' 'embroidary' 'bow' 'beading' 'lace' 'sashes'
#  'hollowout' 'pockets' 'sequined' 'applique' 'button' 'Tiered' 'rivet'
#  'feathers' 'flowers' 'pearls' 'pleat' 'crystal' 'ruched' 'draped'
#  'tassel' 'plain' 'cascading' 'none']
#
# SleeveLength = ['sleevless' 'Petal' 'full' 'butterfly' 'short' 'threequarter'
#  'halfsleeve' 'cap-sleeves' 'turndowncollor' 'threequater' 'capsleeves'
#  'sleeveless' 'sleeevless' 'half' 'urndowncollor' 'thressqatar'
#  'sleveless']

# %%
#correcting the spellings.
inp0['Season'] = inp0['Season'].str.lower().replace({
    'autum': 'autumn',
    'automn': 'autumn',
    })
inp0['NeckLine']=inp0['NeckLine'].str.lower()
inp0['Price']=inp0['Price'].str.lower()
inp0['Material']=inp0['Material'].str.lower()
inp0['Decoration']=inp0['Decoration'].str.lower()
inp0['SleeveLength ']=inp0['SleeveLength'].str.lower().replace({
    'sleevless':'sleeveless',
    'sleeevless':'sleeveless',
    'sleveless':'sleeveless',
    'cap-sleeves':'capsleeves',
'threequarter':'thressqatar',})

# %%
#correcting the Spellings.

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
inp3 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')

# %%
def group_and_calculate_percentage(df, column_name, threshold=50000):
    # Melt the DataFrame to have one row per sale entry
    melted_df = df.melt(id_vars=['Dress_ID', column_name], var_name='Date', value_name='Sales')

    # Function to extract month and determine season
    def extract_month(date_str):
        try:
            return int(date_str.split('-')[1])
        except (IndexError, ValueError):
            return None

    melted_df['Month'] = melted_df['Date'].apply(extract_month)

    # Remove rows where month extraction failed
    melted_df = melted_df.dropna(subset=['Month'])

    def get_season(month):
        if month in [6, 7, 8]:
            return 'Summer'
        elif month in [9, 10, 11]:
            return 'Autumn'
        elif month in [12, 1, 2]:
            return 'Winter'
        elif month in [3, 4, 5]:
            return 'Spring'

    melted_df['Season'] = melted_df['Month'].apply(get_season)

    # Calculate the total sales for each category across all seasons
    total_sales_per_category = melted_df.groupby(column_name)['Sales'].sum().reset_index()

    # Identify categories with total sales less than threshold
    categories_to_group = total_sales_per_category[total_sales_per_category['Sales'] < threshold][column_name].tolist()

    # Replace those categories with "Others"
    melted_df[column_name] = melted_df[column_name].apply(lambda x: 'Others' if x in categories_to_group else x)

    # Group by the specified column and Season, and sum the sales
    grouped_sales = melted_df.groupby([column_name, 'Season'])['Sales'].sum().reset_index()

    # Calculate the total sales for each category
    category_totals = grouped_sales.groupby(column_name)['Sales'].sum().reset_index()

    # Calculate the percentage of each category
    grouped_sales = grouped_sales.merge(category_totals, on=column_name, suffixes=('', '_Total'))
    grouped_sales['Percentage'] = (grouped_sales['Sales'] / grouped_sales['Sales_Total']) * 100

    # Return only the grouped columns and percentage
    return grouped_sales[[column_name, 'Season', 'Percentage']]

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
threshold_value = 50000  # Change threshold as needed
result_Style = group_and_calculate_percentage(inp3, 'Style', threshold=threshold_value)
print("Style Sales Grouped by Season and Percentage")
print(result_Style)
# Out:
# Style Sales Grouped by Season and Percentage
#        Style  Season Percentage
# 0      Brief  Autumn  50.005013
# 1      Brief  Spring   5.359956
# 2      Brief  Summer  26.715988
# 3      Brief  Winter  17.919042
# 4     Casual  Autumn  51.368781
# 5     Casual  Spring   5.525229
# 6     Casual  Summer  25.626827
# 7     Casual  Winter  17.479163
# 8     Others  Autumn  55.314777
# 9     Others  Spring   4.159661
# 10    Others  Summer  21.614048
# 11    Others  Winter  18.911514
# 12      Sexy  Autumn  50.966444
# 13      Sexy  Spring   5.184256
# 14      Sexy  Summer  25.885944
# 15      Sexy  Winter  17.963356
# 16  bohemian  Autumn  54.177699
# 17  bohemian  Spring   5.497924
# 18  bohemian  Summer  23.321325
# 19  bohemian  Winter  17.003053
# 20      cute  Autumn  49.767683
# 21      cute  Spring   5.543278
# 22      cute  Summer  27.062559
# 23      cute  Winter  17.626481
# 24     party  Autumn  52.201461
# 25     party  Spring   5.539838
# 26     party  Summer  24.867425
# 27     party  Winter  17.391276
# 28      sexy  Autumn  49.799356
# 29      sexy  Spring   4.821881
# 30      sexy  Summer  26.167214
# 31      sexy  Winter  19.211549
# 32   vintage  Autumn  50.637966
# 33   vintage  Spring   4.814093
# 34   vintage  Summer  25.943381
# 35   vintage  Winter  18.604561
# 36      work  Autumn  49.829744
# 37      work  Spring   5.255921
# 38      work  Summer  26.780171
# 39      work  Winter  18.134164

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
total_sales_all_styles = total_sales_per_style['Sales'].sum()

# Calculate the percentage of sales for each style
total_sales_per_style['Percentage'] = (total_sales_per_style['Sales'] / total_sales_all_styles) * 100

# Print the result
print(total_sales_per_style[['Style', 'Percentage']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Calculate the percentage of each categories in the "Style" variable.
# ----> 2 total_sales_all_styles = total_sales_per_style['Sales'].sum()
#       4 # Calculate the percentage of sales for each style
#       5 total_sales_per_style['Percentage'] = (total_sales_per_style['Sales'] / total_sales_all_styles) * 100
#
# NameError: name 'total_sales_per_style' is not defined

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.

threshold_value = 50000  # Change threshold as needed
result_SleeveLength = group_and_calculate_percentage(inp3, 'SleeveLength', threshold=threshold_value)
print("Neckline Sales Grouped by Season and Percentage")
print(result_SleeveLength)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 # Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
#       3 threshold_value = 50000  # Change threshold as needed
# ----> 4 result_SleeveLength = group_and_calculate_percentage(inp3, 'SleeveLength', threshold=threshold_value)
#       5 print("Neckline Sales Grouped by Season and Percentage")
#       6 print(result_SleeveLength)
#
# Cell In[28], line 30, in group_and_calculate_percentage(df, column_name, threshold)
#      27 melted_df['Season'] = melted_df['Month'].apply(get_season)
#      29 # Calculate the total sales for each category across all seasons
# ---> 30 total_sales_per_category = melted_df.groupby(column_name)['Sales'].sum().reset_index()
#      32 # Identify categories with total sales less than threshold
#      33 categories_to_group = total_sales_per_category[total_sales_per_category['Sales'] < threshold][column_name].tolist()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1839, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1830 @final
#    1831 def _agg_general(
#    1832     self,
#    (...)
#    1837     npfunc: Callable,
#    1838 ):
# -> 1839     result = self._cython_agg_general(
#    1840         how=alias,
#    1841         alt=npfunc,
#    1842         numeric_only=numeric_only,
#    1843         min_count=min_count,
#    1844     )
#    1845     return result.__finalize__(self.obj, method="groupby")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1905, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1903 def array_func(values: ArrayLike) -> ArrayLike:
#    1904     try:
# -> 1905         result = self.grouper._cython_operation(
#    1906             "aggregate",
#    1907             values,
#    1908             how,
#    1909             axis=data.ndim - 1,
#    1910             min_count=min_count,
#    1911             **kwargs,
#    1912         )
#    1913     except NotImplementedError:
#    1914         # generally if we have numeric_only=False
#    1915         # and non-applicable functions
#    1916         # try to python agg
#    1917         # TODO: shouldn't min_count matter?
#    1918         # TODO: avoid special casing SparseArray here
#    1919         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:324, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     322 if result_mask is not None:
#     323     result_mask = result_mask[None, :]
# --> 324 res = self._call_cython_op(
#     325     values2d,
#     326     min_count=min_count,
#     327     ngroups=ngroups,
#     328     comp_ids=comp_ids,
#     329     mask=mask,
#     330     result_mask=result_mask,
#     331     **kwargs,
#     332 )
#     333 if res.shape[0] == 1:
#     334     return res[0]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:404, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     402 counts = np.zeros(ngroups, dtype=np.int64)
#     403 if self.how in ["min", "max", "mean", "last", "first", "sum"]:
# --> 404     func(
#     405         out=result,
#     406         counts=counts,
#     407         values=values,
#     408         labels=comp_ids,
#     409         min_count=min_count,
#     410         mask=mask,
#     411         result_mask=result_mask,
#     412         is_datetimelike=is_datetimelike,
#     413     )
#     414 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     415     if self.how in ["std", "sem"]:
#
# File groupby.pyx:718, in pandas._libs.groupby.group_sum()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
threshold_value = 50000  # Change threshold as needed
result_neckline = group_and_calculate_percentage(inp3, 'NeckLine', threshold=threshold_value)
print("Sleeve length Sales Grouped by Season and Percentage")
print(result_neckline)
# Out:
# Sleeve length Sales Grouped by Season and Percentage
#           NeckLine  Season Percentage
# 0           Others  Autumn  53.129863
# 1           Others  Spring   5.905891
# 2           Others  Summer  24.393294
# 3           Others  Winter  16.570952
# 4        boat-neck  Autumn  52.721069
# 5        boat-neck  Spring   5.247978
# 6        boat-neck  Summer  24.565967
# 7        boat-neck  Winter  17.464985
# 8           o-neck  Autumn  51.040594
# 9           o-neck  Spring   5.258778
# 10          o-neck  Summer  25.804364
# 11          o-neck  Winter  17.896264
# 12         ruffled  Autumn  46.716188
# 13         ruffled  Spring   6.203363
# 14         ruffled  Summer  29.929083
# 15         ruffled  Winter  17.151366
# 16      slash-neck  Autumn  53.469501
# 17      slash-neck  Spring   5.652377
# 18      slash-neck  Summer  23.995555
# 19      slash-neck  Winter  16.882566
# 20  turndowncollor  Autumn  50.556237
# 21  turndowncollor  Spring   5.101028
# 22  turndowncollor  Summer  26.023417
# 23  turndowncollor  Winter  18.319318
# 24          v-neck  Autumn   50.93334
# 25          v-neck  Spring   5.440879
# 26          v-neck  Summer  25.874559
# 27          v-neck  Winter  17.751221

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
threshold_value = 25000  # Change threshold as needed
result_FabricType = group_and_calculate_percentage(inp3, 'FabricType', threshold=threshold_value)
print("FabricType Sales Grouped by Season and Percentage")
print(result_FabricType)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
#       2 threshold_value = 25000  # Change threshold as needed
# ----> 3 result_FabricType = group_and_calculate_percentage(inp3, 'FabricType', threshold=threshold_value)
#       4 print("FabricType Sales Grouped by Season and Percentage")
#       5 print(result_FabricType)
#
# Cell In[28], line 30, in group_and_calculate_percentage(df, column_name, threshold)
#      27 melted_df['Season'] = melted_df['Month'].apply(get_season)
#      29 # Calculate the total sales for each category across all seasons
# ---> 30 total_sales_per_category = melted_df.groupby(column_name)['Sales'].sum().reset_index()
#      32 # Identify categories with total sales less than threshold
#      33 categories_to_group = total_sales_per_category[total_sales_per_category['Sales'] < threshold][column_name].tolist()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1839, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1830 @final
#    1831 def _agg_general(
#    1832     self,
#    (...)
#    1837     npfunc: Callable,
#    1838 ):
# -> 1839     result = self._cython_agg_general(
#    1840         how=alias,
#    1841         alt=npfunc,
#    1842         numeric_only=numeric_only,
#    1843         min_count=min_count,
#    1844     )
#    1845     return result.__finalize__(self.obj, method="groupby")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1905, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1903 def array_func(values: ArrayLike) -> ArrayLike:
#    1904     try:
# -> 1905         result = self.grouper._cython_operation(
#    1906             "aggregate",
#    1907             values,
#    1908             how,
#    1909             axis=data.ndim - 1,
#    1910             min_count=min_count,
#    1911             **kwargs,
#    1912         )
#    1913     except NotImplementedError:
#    1914         # generally if we have numeric_only=False
#    1915         # and non-applicable functions
#    1916         # try to python agg
#    1917         # TODO: shouldn't min_count matter?
#    1918         # TODO: avoid special casing SparseArray here
#    1919         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:324, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     322 if result_mask is not None:
#     323     result_mask = result_mask[None, :]
# --> 324 res = self._call_cython_op(
#     325     values2d,
#     326     min_count=min_count,
#     327     ngroups=ngroups,
#     328     comp_ids=comp_ids,
#     329     mask=mask,
#     330     result_mask=result_mask,
#     331     **kwargs,
#     332 )
#     333 if res.shape[0] == 1:
#     334     return res[0]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:404, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     402 counts = np.zeros(ngroups, dtype=np.int64)
#     403 if self.how in ["min", "max", "mean", "last", "first", "sum"]:
# --> 404     func(
#     405         out=result,
#     406         counts=counts,
#     407         values=values,
#     408         labels=comp_ids,
#     409         min_count=min_count,
#     410         mask=mask,
#     411         result_mask=result_mask,
#     412         is_datetimelike=is_datetimelike,
#     413     )
#     414 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     415     if self.how in ["std", "sem"]:
#
# File groupby.pyx:718, in pandas._libs.groupby.group_sum()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
threshold_value = 25000  # Change threshold as needed
result_Pattern_Type = group_and_calculate_percentage(inp3, 'Pattern Type', threshold=threshold_value)
print("Pattern Type Sales Grouped by Season and Percentage")
print(result_Pattern_Type)
# Out:
# Pattern Type Sales Grouped by Season and Percentage
#    Pattern Type  Season Percentage
# 0        Others  Autumn  53.503569
# 1        Others  Spring   5.217654
# 2        Others  Summer  23.799471
# 3        Others  Winter  17.479307
# 4        animal  Autumn   50.93126
# 5        animal  Spring    4.71854
# 6        animal  Summer  25.547514
# 7        animal  Winter  18.802687
# 8           dot  Autumn  47.888335
# 9           dot  Spring    5.78275
# 10          dot  Summer  28.710561
# 11          dot  Winter  17.618354
# 12    geometric  Autumn  47.344208
# 13    geometric  Spring   5.758517
# 14    geometric  Summer  28.862553
# 15    geometric  Winter  18.034723
# 16      leopard  Autumn  48.161634
# 17      leopard  Spring   4.606799
# 18      leopard  Summer   27.35584
# 19      leopard  Winter  19.875727
# 20    patchwork  Autumn  51.603691
# 21    patchwork  Spring    5.37066
# 22    patchwork  Summer  25.425989
# 23    patchwork  Winter   17.59966
# 24        print  Autumn  50.709013
# 25        print  Spring   5.190001
# 26        print  Summer   26.06811
# 27        print  Winter  18.032876
# 28        solid  Autumn  51.282081
# 29        solid  Spring    5.38764
# 30        solid  Summer  25.619835
# 31        solid  Winter  17.710445
# 32      striped  Autumn  52.243119
# 33      striped  Spring   4.742917
# 34      striped  Summer  24.954395
# 35      striped  Winter  18.059569

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
threshold_value = 25000  # Change threshold as needed
result_Decoration = group_and_calculate_percentage(inp3, 'Decoration', threshold=threshold_value)
print("Decoration Sales Grouped by Season and Percentage")
print(result_Decoration)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
#       2 threshold_value = 25000  # Change threshold as needed
# ----> 3 result_Decoration = group_and_calculate_percentage(inp3, 'Decoration', threshold=threshold_value)
#       4 print("Decoration Sales Grouped by Season and Percentage")
#       5 print(result_Decoration)
#
# Cell In[28], line 30, in group_and_calculate_percentage(df, column_name, threshold)
#      27 melted_df['Season'] = melted_df['Month'].apply(get_season)
#      29 # Calculate the total sales for each category across all seasons
# ---> 30 total_sales_per_category = melted_df.groupby(column_name)['Sales'].sum().reset_index()
#      32 # Identify categories with total sales less than threshold
#      33 categories_to_group = total_sales_per_category[total_sales_per_category['Sales'] < threshold][column_name].tolist()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1839, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1830 @final
#    1831 def _agg_general(
#    1832     self,
#    (...)
#    1837     npfunc: Callable,
#    1838 ):
# -> 1839     result = self._cython_agg_general(
#    1840         how=alias,
#    1841         alt=npfunc,
#    1842         numeric_only=numeric_only,
#    1843         min_count=min_count,
#    1844     )
#    1845     return result.__finalize__(self.obj, method="groupby")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1905, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1903 def array_func(values: ArrayLike) -> ArrayLike:
#    1904     try:
# -> 1905         result = self.grouper._cython_operation(
#    1906             "aggregate",
#    1907             values,
#    1908             how,
#    1909             axis=data.ndim - 1,
#    1910             min_count=min_count,
#    1911             **kwargs,
#    1912         )
#    1913     except NotImplementedError:
#    1914         # generally if we have numeric_only=False
#    1915         # and non-applicable functions
#    1916         # try to python agg
#    1917         # TODO: shouldn't min_count matter?
#    1918         # TODO: avoid special casing SparseArray here
#    1919         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:324, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     322 if result_mask is not None:
#     323     result_mask = result_mask[None, :]
# --> 324 res = self._call_cython_op(
#     325     values2d,
#     326     min_count=min_count,
#     327     ngroups=ngroups,
#     328     comp_ids=comp_ids,
#     329     mask=mask,
#     330     result_mask=result_mask,
#     331     **kwargs,
#     332 )
#     333 if res.shape[0] == 1:
#     334     return res[0]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:404, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     402 counts = np.zeros(ngroups, dtype=np.int64)
#     403 if self.how in ["min", "max", "mean", "last", "first", "sum"]:
# --> 404     func(
#     405         out=result,
#     406         counts=counts,
#     407         values=values,
#     408         labels=comp_ids,
#     409         min_count=min_count,
#     410         mask=mask,
#     411         result_mask=result_mask,
#     412         is_datetimelike=is_datetimelike,
#     413     )
#     414 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     415     if self.how in ["std", "sem"]:
#
# File groupby.pyx:718, in pandas._libs.groupby.group_sum()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# Style is unordered remaining all are ordered

# %%
# Function to determine season based on month
def get_season(month):
    if month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    elif month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'

# Initialize new columns for each season with 0
inp3['Summer'] = 0
inp3['Autumn'] = 0
inp3['Winter'] = 0
inp3['Spring'] = 0

# Iterate over the columns and accumulate values into respective season columns
for col in inp3.columns[1:]:
    # Check if the column name has the expected date format
    if len(col.split('-')) == 3:
        try:
            month = int(col.split('-')[1])
            season = get_season(month)
            # Add the sales values to the corresponding season column
            inp3[season] += inp3[col]
        except ValueError:
            continue

# Drop original date columns if not needed
inp3.drop(columns=inp3.columns[1:-4], inplace=True)

# Display the resulting DataFrame
print(inp3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 26
#      24     season = get_season(month)
#      25     # Add the sales values to the corresponding season column
# ---> 26     inp3[season] += inp3[col]
#      27 except ValueError:
#      28     continue
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12279, in NDFrame.__iadd__(self, other)
#   12276 @final
#   12277 def __iadd__(self, other) -> Self:
#   12278     # error: Unsupported left operand type for + ("Type[NDFrame]")
# > 12279     return self._inplace_method(other, type(self).__add__)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12255, in NDFrame._inplace_method(self, other, op)
#   12250 @final
#   12251 def _inplace_method(self, other, op) -> Self:
#   12252     """
#   12253     Wrap arithmetic method to operate inplace.
#   12254     """
# > 12255     result = op(self, other)
#   12257     if self.ndim == 1 and result._indexed_same(self) and result.dtype == self.dtype:
#   12258         # GH#36498 this inplace op can _actually_ be inplace.
#   12259         # Item "ArrayManager" of "Union[ArrayManager, SingleArrayManager,
#   12260         # BlockManager, SingleBlockManager]" has no attribute "setitem_inplace"
#   12261         self._mgr.setitem_inplace(  # type: ignore[union-attr]
#   12262             slice(None), result._values
#   12263         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# -> 5819     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
import numpy as np
# Calculate the 75th percentile of the "Autumn" column
percentile_75 = np.percentile(inp3['Autumn'].dropna(), 75)

# Calculate the maximum value in the "Autumn" column
max_value = inp3['Autumn'].max()

# Calculate the approximate difference
difference = max_value - percentile_75

print(f"Approximate difference between maximum and 75th percentile in 'Autumn' column: {difference}")
# Out:
# Approximate difference between maximum and 75th percentile in 'Autumn' column: 52406.0

# %%
# Describe the numerical variale: "Autumn".
inp3['Autumn'].describe()
# Out:
# count     479.000000
# mean      320.100209
# std       610.360681
# min         1.000000
# 25%        37.000000
# 50%       129.000000
# 75%       334.000000
# max      7240.000000
# Name: Autumn, dtype: float64

# %%
# plot the boxplot of "Autumn" column.
df = pd.DataFrame(inp3)

# Plotting the boxplot of the "Autumn" column
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Autumn'])
plt.title('Boxplot of Autumn Column')
plt.xlabel('Autumn')
plt.grid(True)
plt.savefig('boxplot.png')
print("Boxplot saved as 'boxplot.png'.")
# Out:
# Boxplot saved as 'boxplot.png'.

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
max_values = {}
quantile_99 = {}
for season in ['Summer', 'Autumn', 'Winter', 'Spring']:
    max_values[season] = df[season].max()
    quantile_99[season] = np.percentile(df[season].dropna(), 99)

# Calculate differences
differences = {season: max_values[season] - quantile_99[season] for season in ['Summer', 'Autumn', 'Winter', 'Spring']}

# Determine the season with the highest difference
season_with_highest_difference = max(differences, key=differences.get)
highest_difference = differences[season_with_highest_difference]

print(f"Season with the highest difference: {season_with_highest_difference}")
print(f"Highest difference between max and 99th quantile: {highest_difference}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 quantile_99 = {}
#       3 for season in ['Summer', 'Autumn', 'Winter', 'Spring']:
# ----> 4     max_values[season] = df[season].max()
#       5     quantile_99[season] = np.percentile(df[season].dropna(), 99)
#       7 # Calculate differences
#
# NameError: name 'df' is not defined

# %%
# Find the maximum and 50th percentile of Winter season.
max_winter = inp3['Winter'].max()
percentile_50 = np.percentile(inp3['Winter'].dropna(), 50)

print(f"Maximum value of Winter column: {max_winter}")
print(f"50th percentile (median) of Winter column: {percentile_50}")
# Out:
# Maximum value of Winter column: 7479
# 50th percentile (median) of Winter column: 4.0

# %%
# Find the maximum and 50th percentile of Summer season.
max_Summer = inp3['Summer'].max()
percentile_50 = np.percentile(inp3['Summer'].dropna(), 50)

print(f"Maximum value of Summer column: {max_Summer}")
print(f"50th percentile (median) of Summer column: {percentile_50}")
# Out:
# Maximum value of Summer column: 29528
# 50th percentile (median) of Summer column: 282.0

# %%
# Find the maximum and 50th percentile of Spring season.
max_Spring = inp3['Spring'].max()
percentile_50 = np.percentile(inp3['Spring'].dropna(), 50)

print(f"Maximum value of Winter column: {max_Spring}")
print(f"50th percentile (median) of Spring column: {percentile_50}")
# Out:
# Maximum value of Winter column: 7374
# 50th percentile (median) of Spring column: 110.0

# %%
# Find the maximum and 50th percentile of Autumn season.
max_Autumn = inp3['Autumn'].max()
percentile_50 = np.percentile(inp3['Autumn'].dropna(), 50)

print(f"Maximum value of Autumn column: {max_Autumn}")
print(f"50th percentile (median) of Autumn column: {percentile_50}")
# Out:
# Maximum value of Autumn column: 7240
# 50th percentile (median) of Autumn column: 129.0
